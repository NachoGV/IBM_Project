# %% [markdown]
# # Unraveling Wine Quality Patterns - ETL
#     IBM Data Science Capstone Project

# %% [markdown]
# ## Environment Set Up

# %% [markdown]
# ### Requisites

# %%
# !pip install pandas ucimlrepo scikit-learn

# %% [markdown]
# ### Imports

# %%
import pandas as pd 
from ucimlrepo import fetch_ucirepo
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ### Config

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Feature Engineering
#
# As there are no missing values, we will not need to impute any data.
#
# The following changes will be made:
# - Ensure types are either integer, float or category
# - One hot encoding of color column for its use in regression - Keeping the original column for its use in classification
# - Normalization of all features - No the taget columns

# %%
# Load the dataset
wine_quality = fetch_ucirepo(id=186) 
wines = pd.DataFrame(wine_quality.data.original)
wines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# One hot encoding
wines = pd.get_dummies(wines, columns=['color'])
wines['color'] = wine_quality.data.original['color']
wines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4              0.70         0.00             1.9      0.076
# 1               7.8              0.88         0.00             2.6      0.098
# 2               7.8              0.76         0.04             2.3      0.092
# 3              11.2              0.28         0.56             1.9      0.075
# 4               7.4              0.70         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 6492            6.2              0.21         0.29             1.6      0.039
# 6493            6.6              0.32         0.36             8.0      0.047
# 6494            6.5              0.24         0.19             1.2      0.041
# 6495            5.5              0.29         0.30             1.1      0.022
# 6496            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
# Normalize data
scaler = StandardScaler()
wines.iloc[:, :-4] = scaler.fit_transform(wines.iloc[:, :-4])
wines
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0          0.142473          2.188833    -2.192833       -0.744778   0.569958
# 1          0.451036          3.282235    -2.192833       -0.597640   1.197975
# 2          0.451036          2.553300    -1.917553       -0.660699   1.026697
# 3          3.073817         -0.362438     1.661085       -0.744778   0.541412
# 4          0.142473          2.188833    -2.192833       -0.744778   0.569958
# ...             ...               ...          ...             ...        ...
# 6492      -0.783214         -0.787650    -0.197054       -0.807837  -0.486252
# 6493      -0.474652         -0.119460     0.284686        0.537425  -0.257883
# 6494      -0.551792         -0.605417    -0.885253       -0.891916  -0.429160
# 6495      -1.323198         -0.301694    -0.128234       -0.912936  -0.971538
# 6496      -0.937495         -0.787650     0.422326       -0.975995  -1.028631
#
# ...

# %%
# Types
wines['color'] = wines['color'].astype('category')
wines.dtypes
# Out:
# fixed_acidity            float64
# volatile_acidity         float64
# citric_acid              float64
# residual_sugar           float64
# chlorides                float64
# free_sulfur_dioxide      float64
# total_sulfur_dioxide     float64
# density                  float64
# pH                       float64
# sulphates                float64
# alcohol                  float64
# quality                    int64
# color_red                  uint8
# color_white                uint8
# color                   category
# dtype: object

# %%
# Store the dataset
wines.to_csv('./data/wine_quality_preprocessed.csv', index=False)
